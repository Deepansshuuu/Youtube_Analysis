# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('USvideos.csv')

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE      17.14.11
# 1  1ZAPwfrtAFY      17.14.11
# 2  5qpjK5DgCt4      17.14.11
# 3  puqaWrEC7tY      17.14.11
# 4  d380meD0W0M      17.14.11
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22  2017-11-13T17:13:01.000Z
# 1           24  2017-11-13T07:30:00.000Z
# 2           23  2017-11-12T19:05:24.000Z
# 3           24  2017-11-13T11:00:04.000Z
# 4           24  2017-11-12T18:01:41.000Z
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  comment_count                                  thumbnail_link  \
# 0      2966          15954  https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg
# 1      6146          12703  https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg
# 2      5339           8181  https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg
# 3       666           2146  https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg
# 4      1989          17518  https://i.ytimg.com/vi/d380meD0W0M/default.jpg
#
#    comments_disabled  ratings_disabled  video_error_or_removed  \
# 0              False             False                   False
# 1              False             False                   False
# 2              False             False                   False
# 3              False             False                   False
# 4              False             False                   False
#
#                                          description
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1  One year after the presidential election, John...
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3  Today we find out if Link is a Nickelback amat...
# 4  I know it's been a while since we did this sho...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
df.isnull().sum()
# Out:
# video_id                    0
# trending_date               0
# title                       0
# channel_title               0
# category_id                 0
# publish_time                0
# tags                        0
# views                       0
# likes                       0
# dislikes                    0
# comment_count               0
# thumbnail_link              0
# comments_disabled           0
# ratings_disabled            0
# video_error_or_removed      0
# description               570
# dtype: int64

# %%
dup_check = df.duplicated(subset=['video_id','trending_date'],keep=False)
df[dup_check].sort_values(['video_id','trending_date'])
# Out:
#           video_id trending_date  \
# 34757  1RZYOeQeIXE      18.15.05
# 34906  1RZYOeQeIXE      18.15.05
# 34768  1U1u5aKU3AY      18.15.05
# 34917  1U1u5aKU3AY      18.15.05
# 34799  2PH7dK6SLC8      18.15.05
# ...            ...           ...
# 34903  xhs8tf1v__w      18.15.05
# 34793  y_WoOYybCro      18.15.05
# 34942  y_WoOYybCro      18.15.05
# 34796  zcEE8J2Bqa8      18.15.05
# 34945  zcEE8J2Bqa8      18.15.05
#
#                                                    title  channel_title  \
# 34757   Sarah Paulson Gets Scared During '5 Second Rule'   TheEllenShow
# 34906   Sarah Paulson Gets Scared During '5 Second Rule'   TheEllenShow
# 34768  New lava fissures fuel fears of eruption in Ha...            CNN
# 34917  New lava fissures fuel fears of eruption in Ha...            CNN
# 34799                             John Mayer - New Light  johnmayerVEVO
# ...                                                  ...            ...
# 34903  Terry Crews Answers the Web's Most Searched Qu...          WIRED
# 34793  How I Became The Fresh Prince of Bel-Air | STO...     Will Smith
# 34942  How I Became The Fresh Prince of Bel-Air | STO...     Will Smith
# 34796                         The Goblin - JACK AND DEAN  Jack and Dean
# 34945                         The Goblin - JACK AND DEAN  Jack and Dean
#
#        category_id              publish_time  \
# 34757           24  2018-05-14T13:00:00.000Z
# 34906           24  2018-05-14T13:00:00.000Z
# 34768           25  2018-05-13T19:30:53.000Z
# 34917           25  2018-05-13T19:30:53.000Z
# 34799           10  2018-05-10T17:00:01.000Z
# ...            ...                       ...
# 34903           24  2018-05-14T16:00:29.000Z
# 34793           24  2018-05-10T16:08:58.000Z
# 34942           24  2018-05-10T16:08:58.000Z
# 34796           23  2018-05-11T18:27:01.000Z
# 34945           23  2018-05-11T18:27:01.000Z
#
#                                                     tags    views   likes  \
# 34757  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786   19880
# 34906  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786   19880
# 34768  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387    1488
# 34917  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387    1488
# 34799  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...  1201548   51670
# ...                                                  ...      ...     ...
# 34903  autocomplete|"deadpool 2"|"google autocomplete...   343967   16988
# 34793  comedy|"entertainment"|"will smith"|"will"|"sm...  2055638  120377
# 34942  comedy|"entertainment"|"will smith"|"will"|"sm...  2055638  120377
# 34796  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...   165617   20572
# 34945  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...   165617   20572
#
#        dislikes  comment_count  \
# 34757       248            669
# 34906       248            669
# 34768       251           1087
# 34917       251           1087
# 34799       964           4264
# ...         ...            ...
# 34903       132           1308
# 34793       752           4872
# 34942       752           4872
# 34796       140           1407
# 34945       140           1407
#
#                                        thumbnail_link  comments_disabled  \
# 34757  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34906  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34768  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34917  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34799  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg              False
# ...                                               ...                ...
# 34903  https://i.ytimg.com/vi/xhs8tf1v__w/default.jpg              False
# 34793  https://i.ytimg.com/vi/y_WoOYybCro/default.jpg              False
# 34942  https://i.ytimg.com/vi/y_WoOYybCro/default.jpg              False
# 34796  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg              False
# 34945  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 34757             False                   False
# 34906             False                   False
# 34768             False                   False
# 34917             False                   False
# 34799             False                   False
# ...                 ...                     ...
# 34903             False                   False
# 34793             False                   False
# 34942             False                   False
# 34796             False                   False
# 34945             False                   False
#
#                                              description
# 34757  Sarah Paulson agreed to play a friendly game o...
# 34906  Sarah Paulson agreed to play a friendly game o...
# 34768  Three new fissures have opened on Hawaii's Big...
# 34917  Three new fissures have opened on Hawaii's Big...
# 34799  Spotify: http://radi.al/NewLightSpotifyApple: ...
# ...                                                  ...
# 34903  Terry Crews takes the WIRED Autocomplete Inter...
# 34793  The full story of how an ex-girlfriend, Arseni...
# 34942  The full story of how an ex-girlfriend, Arseni...
# 34796  That? That's a goblin living under the stairs....
# 34945  That? That's a goblin living under the stairs....
#
# [100 rows x 16 columns]

# %%
df.drop_duplicates()
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40901 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
df[dup_check].iloc[-2:].T
df[dup_check].sort_values(['video_id', 'trending_date']).groupby(['video_id', 'trending_date']).head(2)
# Out:
#           video_id trending_date  \
# 34757  1RZYOeQeIXE      18.15.05
# 34906  1RZYOeQeIXE      18.15.05
# 34768  1U1u5aKU3AY      18.15.05
# 34917  1U1u5aKU3AY      18.15.05
# 34799  2PH7dK6SLC8      18.15.05
# ...            ...           ...
# 34903  xhs8tf1v__w      18.15.05
# 34793  y_WoOYybCro      18.15.05
# 34942  y_WoOYybCro      18.15.05
# 34796  zcEE8J2Bqa8      18.15.05
# 34945  zcEE8J2Bqa8      18.15.05
#
#                                                    title  channel_title  \
# 34757   Sarah Paulson Gets Scared During '5 Second Rule'   TheEllenShow
# 34906   Sarah Paulson Gets Scared During '5 Second Rule'   TheEllenShow
# 34768  New lava fissures fuel fears of eruption in Ha...            CNN
# 34917  New lava fissures fuel fears of eruption in Ha...            CNN
# 34799                             John Mayer - New Light  johnmayerVEVO
# ...                                                  ...            ...
# 34903  Terry Crews Answers the Web's Most Searched Qu...          WIRED
# 34793  How I Became The Fresh Prince of Bel-Air | STO...     Will Smith
# 34942  How I Became The Fresh Prince of Bel-Air | STO...     Will Smith
# 34796                         The Goblin - JACK AND DEAN  Jack and Dean
# 34945                         The Goblin - JACK AND DEAN  Jack and Dean
#
#        category_id              publish_time  \
# 34757           24  2018-05-14T13:00:00.000Z
# 34906           24  2018-05-14T13:00:00.000Z
# 34768           25  2018-05-13T19:30:53.000Z
# 34917           25  2018-05-13T19:30:53.000Z
# 34799           10  2018-05-10T17:00:01.000Z
# ...            ...                       ...
# 34903           24  2018-05-14T16:00:29.000Z
# 34793           24  2018-05-10T16:08:58.000Z
# 34942           24  2018-05-10T16:08:58.000Z
# 34796           23  2018-05-11T18:27:01.000Z
# 34945           23  2018-05-11T18:27:01.000Z
#
#                                                     tags    views   likes  \
# 34757  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786   19880
# 34906  ellen|"ellen degeneres"|"the ellen show"|"seas...   704786   19880
# 34768  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387    1488
# 34917  latest News|"Happening Now"|"CNN"|"lava"|"hawa...   241387    1488
# 34799  John|"Mayer"|"New"|"Light"|"Snack"|"Money"|"Po...  1201548   51670
# ...                                                  ...      ...     ...
# 34903  autocomplete|"deadpool 2"|"google autocomplete...   343967   16988
# 34793  comedy|"entertainment"|"will smith"|"will"|"sm...  2055638  120377
# 34942  comedy|"entertainment"|"will smith"|"will"|"sm...  2055638  120377
# 34796  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...   165617   20572
# 34945  Jack and Dean|"OMFGItsJackAndDean"|"Jack Howar...   165617   20572
#
#        dislikes  comment_count  \
# 34757       248            669
# 34906       248            669
# 34768       251           1087
# 34917       251           1087
# 34799       964           4264
# ...         ...            ...
# 34903       132           1308
# 34793       752           4872
# 34942       752           4872
# 34796       140           1407
# 34945       140           1407
#
#                                        thumbnail_link  comments_disabled  \
# 34757  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34906  https://i.ytimg.com/vi/1RZYOeQeIXE/default.jpg              False
# 34768  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34917  https://i.ytimg.com/vi/1U1u5aKU3AY/default.jpg              False
# 34799  https://i.ytimg.com/vi/2PH7dK6SLC8/default.jpg              False
# ...                                               ...                ...
# 34903  https://i.ytimg.com/vi/xhs8tf1v__w/default.jpg              False
# 34793  https://i.ytimg.com/vi/y_WoOYybCro/default.jpg              False
# 34942  https://i.ytimg.com/vi/y_WoOYybCro/default.jpg              False
# 34796  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg              False
# 34945  https://i.ytimg.com/vi/zcEE8J2Bqa8/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 34757             False                   False
# 34906             False                   False
# 34768             False                   False
# 34917             False                   False
# 34799             False                   False
# ...                 ...                     ...
# 34903             False                   False
# 34793             False                   False
# 34942             False                   False
# 34796             False                   False
# 34945             False                   False
#
#                                              description
# 34757  Sarah Paulson agreed to play a friendly game o...
# 34906  Sarah Paulson agreed to play a friendly game o...
# 34768  Three new fissures have opened on Hawaii's Big...
# 34917  Three new fissures have opened on Hawaii's Big...
# 34799  Spotify: http://radi.al/NewLightSpotifyApple: ...
# ...                                                  ...
# 34903  Terry Crews takes the WIRED Autocomplete Inter...
# 34793  The full story of how an ex-girlfriend, Arseni...
# 34942  The full story of how an ex-girlfriend, Arseni...
# 34796  That? That's a goblin living under the stairs....
# 34945  That? That's a goblin living under the stairs....
#
# [100 rows x 16 columns]

# %%
df[df.duplicated(keep=False)].sort_values('video_id')
df.duplicated(subset=['video_id', 'trending_date']).sum()
# Out:
# np.int64(50)

# %%
df.drop_duplicates()
# Out:
#           video_id trending_date  \
# 0      2kyS6SvSYSE      17.14.11
# 1      1ZAPwfrtAFY      17.14.11
# 2      5qpjK5DgCt4      17.14.11
# 3      puqaWrEC7tY      17.14.11
# 4      d380meD0W0M      17.14.11
# ...            ...           ...
# 40944  BZt0qjTWNhw      18.14.06
# 40945  1h7KV2sjUWY      18.14.06
# 40946  D6Oy4LfoqsU      18.14.06
# 40947  oV0zkMe1K8s      18.14.06
# 40948  ooyjaVdt-jA      18.14.06
#
#                                                    title  \
# 0                     WE WANT TO TALK ABOUT OUR MARRIAGE
# 1      The Trump Presidency: Last Week Tonight with J...
# 2      Racist Superman | Rudy Mancuso, King Bach & Le...
# 3                       Nickelback Lyrics: Real or Fake?
# 4                               I Dare You: GOING BALD!?
# ...                                                  ...
# 40944                       The Cat Who Caught the Laser
# 40945                         True Facts : Ant Mutualism
# 40946  I GAVE SAFIYA NYGAARD A PERFECT HAIR MAKEOVER ...
# 40947                How Black Panther Should Have Ended
# 40948  Official Call of Duty®: Black Ops 4 — Multipla...
#
#                   channel_title  category_id              publish_time  \
# 0                  CaseyNeistat           22  2017-11-13T17:13:01.000Z
# 1               LastWeekTonight           24  2017-11-13T07:30:00.000Z
# 2                  Rudy Mancuso           23  2017-11-12T19:05:24.000Z
# 3         Good Mythical Morning           24  2017-11-13T11:00:04.000Z
# 4                      nigahiga           24  2017-11-12T18:01:41.000Z
# ...                         ...          ...                       ...
# 40944             AaronsAnimals           15  2018-05-18T13:00:04.000Z
# 40945                  zefrank1           22  2018-05-18T01:00:06.000Z
# 40946                Brad Mondo           24  2018-05-18T17:34:22.000Z
# 40947  How It Should Have Ended            1  2018-05-17T17:00:04.000Z
# 40948              Call of Duty           20  2018-05-17T17:09:38.000Z
#
#                                                     tags     views   likes  \
# 0                                        SHANtell martin    748374   57527
# 1      last week tonight trump presidency|"last week ...   2418783   97185
# 2      racist superman|"rudy"|"mancuso"|"king"|"bach"...   3191434  146033
# 3      rhett and link|"gmm"|"good mythical morning"|"...    343168   10172
# 4      ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...   2095731  132235
# ...                                                  ...       ...     ...
# 40944  aarons animals|"aarons"|"animals"|"cat"|"cats"...   1685609   38160
# 40945                                             [none]   1064798   60008
# 40946  I gave safiya nygaard a perfect hair makeover ...   1066451   48068
# 40947  Black Panther|"HISHE"|"Marvel"|"Infinity War"|...   5660813  192957
# 40948      call of duty|"cod"|"activision"|"Black Ops 4"  10306119  357079
#
#        dislikes  comment_count  \
# 0          2966          15954
# 1          6146          12703
# 2          5339           8181
# 3           666           2146
# 4          1989          17518
# ...         ...            ...
# 40944      1385           2657
# 40945       382           3936
# 40946      1032           3992
# 40947      2846          13088
# 40948    212976         144795
#
#                                        thumbnail_link  comments_disabled  \
# 0      https://i.ytimg.com/vi/2kyS6SvSYSE/default.jpg              False
# 1      https://i.ytimg.com/vi/1ZAPwfrtAFY/default.jpg              False
# 2      https://i.ytimg.com/vi/5qpjK5DgCt4/default.jpg              False
# 3      https://i.ytimg.com/vi/puqaWrEC7tY/default.jpg              False
# 4      https://i.ytimg.com/vi/d380meD0W0M/default.jpg              False
# ...                                               ...                ...
# 40944  https://i.ytimg.com/vi/BZt0qjTWNhw/default.jpg              False
# 40945  https://i.ytimg.com/vi/1h7KV2sjUWY/default.jpg              False
# 40946  https://i.ytimg.com/vi/D6Oy4LfoqsU/default.jpg              False
# 40947  https://i.ytimg.com/vi/oV0zkMe1K8s/default.jpg              False
# 40948  https://i.ytimg.com/vi/ooyjaVdt-jA/default.jpg              False
#
#        ratings_disabled  video_error_or_removed  \
# 0                 False                   False
# 1                 False                   False
# 2                 False                   False
# 3                 False                   False
# 4                 False                   False
# ...                 ...                     ...
# 40944             False                   False
# 40945             False                   False
# 40946             False                   False
# 40947             False                   False
# 40948             False                   False
#
#                                              description
# 0      SHANTELL'S CHANNEL - https://www.youtube.com/s...
# 1      One year after the presidential election, John...
# 2      WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...
# 3      Today we find out if Link is a Nickelback amat...
# 4      I know it's been a while since we did this sho...
# ...                                                  ...
# 40944     The Cat Who Caught the Laser - Aaron's Animals
# 40945                                                NaN
# 40946  I had so much fun transforming Safiyas hair in...
# 40947  How Black Panther Should Have EndedWatch More ...
# 40948  Call of Duty: Black Ops 4 Multiplayer raises t...
#
# [40901 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  object
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  object
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
# dtypes: bool(3), int64(5), object(8)
# memory usage: 4.2+ MB

# %%
df['trending_date']=pd.to_datetime(df['trending_date'],format='%y.%d.%m')

# %%
df['publish_time']=pd.to_datetime(df['publish_time'])
df['publish_day']= df['publish_time'].dt.day_name()
df['publish_month']= df['publish_time'].dt.month
df['publish_hour']= df['publish_time'].dt.hour

# %%
category_map = {
    1: "Film & Animation",
    2: "Autos & Vehicles",
    10: "Music",
    15: "Pets & Animals",
    17: "Sports",
    18: "Short Movies",
    19: "Travel & Events",
    20: "Gaming",
    21: "Video blogging",
    22: "People & Blogs",
    23: "Comedy",
    24: "Entertainment",
    25: "News & Politics",
    26: "Howto & Style",
    27: "Education",
    28: "Science & Technology",
    29: "Nonprofits & Activism"
}

df['category_id'] = df['category_id'].astype(int)

df['category_name'] = df['category_id'].map(category_map).fillna("Other")

# %%
df['title_length'] = df['title'].fillna('').str.len()
df['description_length'] = df['description'].fillna('').str.len()

# %%
view_safe= df['views'].replace(0,np.nan)

df['like_ratio']=df['likes']/view_safe
df['comment_ratio']=df['comment_count']/view_safe

# %%
df['description_length']=df['description'].fillna("")

# %%
df.head()
# Out:
#       video_id trending_date  \
# 0  2kyS6SvSYSE    2017-11-14
# 1  1ZAPwfrtAFY    2017-11-14
# 2  5qpjK5DgCt4    2017-11-14
# 3  puqaWrEC7tY    2017-11-14
# 4  d380meD0W0M    2017-11-14
#
#                                                title          channel_title  \
# 0                 WE WANT TO TALK ABOUT OUR MARRIAGE           CaseyNeistat
# 1  The Trump Presidency: Last Week Tonight with J...        LastWeekTonight
# 2  Racist Superman | Rudy Mancuso, King Bach & Le...           Rudy Mancuso
# 3                   Nickelback Lyrics: Real or Fake?  Good Mythical Morning
# 4                           I Dare You: GOING BALD!?               nigahiga
#
#    category_id              publish_time  \
# 0           22 2017-11-13 17:13:01+00:00
# 1           24 2017-11-13 07:30:00+00:00
# 2           23 2017-11-12 19:05:24+00:00
# 3           24 2017-11-13 11:00:04+00:00
# 4           24 2017-11-12 18:01:41+00:00
#
#                                                 tags    views   likes  \
# 0                                    SHANtell martin   748374   57527
# 1  last week tonight trump presidency|"last week ...  2418783   97185
# 2  racist superman|"rudy"|"mancuso"|"king"|"bach"...  3191434  146033
# 3  rhett and link|"gmm"|"good mythical morning"|"...   343168   10172
# 4  ryan|"higa"|"higatv"|"nigahiga"|"i dare you"|"...  2095731  132235
#
#    dislikes  ...  video_error_or_removed  \
# 0      2966  ...                   False
# 1      6146  ...                   False
# 2      5339  ...                   False
# 3       666  ...                   False
# 4      1989  ...                   False
#
#                                          description  publish_day  \
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...       Monday
# 1  One year after the presidential election, John...       Monday
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...       Sunday
# 3  Today we find out if Link is a Nickelback amat...       Monday
# 4  I know it's been a while since we did this sho...       Sunday
#
#    publish_month  publish_hour   category_name title_length  \
# 0             11            17  People & Blogs           34
# 1             11             7   Entertainment           62
# 2             11            19          Comedy           53
# 3             11            11   Entertainment           32
# 4             11            18   Entertainment           24
#
#                                   description_length  like_ratio comment_ratio
# 0  SHANTELL'S CHANNEL - https://www.youtube.com/s...    0.076869      0.021318
# 1  One year after the presidential election, John...    0.040179      0.005252
# 2  WATCH MY PREVIOUS VIDEO ▶ \n\nSUBSCRIBE ► http...    0.045758      0.002563
# 3  Today we find out if Link is a Nickelback amat...    0.029641      0.006253
# 4  I know it's been a while since we did this sho...    0.063097      0.008359
#
# [5 rows x 24 columns]

# %%
df.to_csv('clean_usa.csv')

# %%
df['publish_time'] = pd.to_datetime(df['publish_time']).dt.tz_localize(None)
df['trending_date'] = pd.to_datetime(df['trending_date'])

df['days_to_trend'] = (df['trending_date'] - df['publish_time']).dt.days

# %%
df['days_to_trend'].head(5)
# Out:
# 0    0
# 1    0
# 2    1
# 3    0
# 4    1
# Name: days_to_trend, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40949 entries, 0 to 40948
# Data columns (total 25 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   video_id                40949 non-null  object
#  1   trending_date           40949 non-null  datetime64[ns]
#  2   title                   40949 non-null  object
#  3   channel_title           40949 non-null  object
#  4   category_id             40949 non-null  int64
#  5   publish_time            40949 non-null  datetime64[ns]
#  6   tags                    40949 non-null  object
#  7   views                   40949 non-null  int64
#  8   likes                   40949 non-null  int64
#  9   dislikes                40949 non-null  int64
#  10  comment_count           40949 non-null  int64
#  11  thumbnail_link          40949 non-null  object
#  12  comments_disabled       40949 non-null  bool
#  13  ratings_disabled        40949 non-null  bool
#  14  video_error_or_removed  40949 non-null  bool
#  15  description             40379 non-null  object
#  16  publish_day             40949 non-null  object
#  17  publish_month           40949 non-null  int32
#  18  publish_hour            40949 non-null  int32
#  19  category_name           40949 non-null  object
#  20  title_length            40949 non-null  int64
#  21  description_length      40949 non-null  object
#  22  like_ratio              40949 non-null  float64
#  23  comment_ratio           40949 non-null  float64
#  24  days_to_trend           40949 non-null  int64
# dtypes: bool(3), datetime64[ns](2), float64(2), int32(2), int64(7), object(9)
# memory usage: 6.7+ MB

# %%
df.to_csv('final_usa.csv')
